# %% [markdown]
# # Importing Libraries

# %%
import warnings 
warnings.filterwarnings('ignore')
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from math import sqrt
import numpy as np 
import pandas as pd 
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import seaborn as sns
from pandas.plotting import lag_plot
from pandas import datetime
import time
import os
import pandas as pd
import math
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import GRU, LSTM, Bidirectional, Dense, Flatten, Conv1D, BatchNormalization, LeakyReLU, Dropout, SimpleRNN, GRU, Bidirectional
from pickle import load
from pandas.plotting import lag_plot
from pandas import DataFrame
from pandas import concat
import mplfinance as mpf
import matplotlib.dates as mdates
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

# %%
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.naive_bayes import MultinomialNB
from sklearn import linear_model
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Importing Dataset

# %%
dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m-%d')
data = pd.read_csv('^NSEI.csv', sep=',', parse_dates=['Date'], index_col='Date',date_parser=dateparse)
plt.figure(figsize=(16,8))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Open Prices')
plt.plot(data['Open']);

# %% [markdown]
# # EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 498 entries, 2021-11-09 to 2023-11-09
# Data columns (total 6 columns):
# Open         498 non-null float64
# High         498 non-null float64
# Low          498 non-null float64
# Close        498 non-null float64
# Adj Close    498 non-null float64
# Volume       498 non-null int64
# dtypes: float64(5), int64(1)
# memory usage: 27.2 KB

# %%
data.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-11-09  18084.349609  18112.599609  17983.050781  18044.250000
# 2021-11-10  17973.449219  18061.250000  17915.000000  18017.199219
# 2021-11-11  17967.449219  17971.349609  17798.199219  17873.599609
# 2021-11-12  17977.599609  18123.000000  17905.900391  18102.750000
# 2021-11-15  18140.949219  18210.150391  18071.300781  18109.449219
#
#                Adj Close  Volume
# Date
# 2021-11-09  18044.250000  270200
# 2021-11-10  18017.199219  261400
# 2021-11-11  17873.599609  232100
# 2021-11-12  18102.750000  249100
# 2021-11-15  18109.449219  280400

# %%
data.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2023-11-03  19241.000000  19276.250000  19210.900391  19230.599609
# 2023-11-06  19345.849609  19423.000000  19309.699219  19411.750000
# 2023-11-07  19404.050781  19423.500000  19329.099609  19406.699219
# 2023-11-08  19449.599609  19464.400391  19401.500000  19443.500000
# 2023-11-09  19457.400391  19463.900391  19402.699219  19446.000000
#
#                Adj Close  Volume
# Date
# 2023-11-03  19230.599609  189500
# 2023-11-06  19411.750000  180700
# 2023-11-07  19406.699219  198700
# 2023-11-08  19443.500000  195000
# 2023-11-09  19446.000000       0

# %%
data.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count    498.000000    498.000000    498.000000    498.000000    498.000000
# mean   17855.341675  17934.490340  17749.474364  17845.278436  17845.278436
# std     1078.276795   1059.456148   1093.983762   1077.364098   1077.364098
# min    15272.650391  15382.500000  15183.400391  15293.500000  15293.500000
# 25%    17183.261719  17288.413086  17056.000000  17168.162598  17168.162598
# 50%    17769.450195  17826.674805  17659.575195  17758.875000  17758.875000
# 75%    18545.249512  18598.000488  18436.349609  18509.399902  18509.399902
# max    20156.449219  20222.449219  20129.699219  20192.349609  20192.349609
#
#               Volume
# count     498.000000
# mean   269713.654618
# std     77173.066985
# min         0.000000
# 25%    226675.000000
# 50%    257200.000000
# 75%    294775.000000
# max    696500.000000

# %%
data.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# # Data Visulization

# %%
plt.figure(figsize=(12,8))
lag_plot(data['Open'], lag=1)
plt.title('Autocorrelation plot')
plt.grid(True)
plt.legend();


values = DataFrame(data['Open'].values)
dataframe = concat([values.shift(120), values], axis=1)
dataframe.columns = ['t-1', 't+1']
result = dataframe.corr()
print(result)
# Out:
# No handles with labels found to put in legend.
#           t-1       t+1
# t-1  1.000000  0.106725
# t+1  0.106725  1.000000

# %%
plt.figure(figsize=(12, 6))
plt.plot(data['Close'], label='Close Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock Price Over Time')
plt.legend()
plt.show()

# %%
mpf.plot(data, type='candle', style='charles', title='Candlestick Chart', volume=True)

# %%
train_data, test_data = data[0:int(len(data)*0.9)], data[int(len(data)*0.9):]
plt.figure(figsize=(16,8))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Open Prices')
plt.plot(data['Open'], 'green', label='Train data')
plt.plot(test_data['Open'], 'blue', label='Test data')
plt.legend()

# %%
sns.histplot(data['Volume'], kde=True)
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.title('Volume Distribution')
plt.show()

# %%
correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
df = data
x = mdates.date2num(df.index)

width = 0.2  # Adjust the width as needed

plt.bar(x - width, df['Open'], width=width, label='Open')
plt.bar(x, df['High'], width=width, label='High')
plt.bar(x + width, df['Low'], width=width, label='Low')
plt.bar(x + 2 * width, df['Close'], width=width, label='Close')

plt.xlabel('Data Point')
plt.ylabel('Price')
plt.title('HDFC Prices')
plt.legend()
plt.show()

# %%
sns.boxplot(data=df[['Open', 'High', 'Low', 'Close']])
plt.title('Price Distribution')
# Out:
# Text(0.5, 1.0, 'Price Distribution')

# %% [markdown]
# # Model Building

# %%
train = train_data.iloc[:, 0:1].values 
scaler = MinMaxScaler() 
train_scaled = scaler.fit_transform(train)
timesteps = 7
X_train = []
y_train = []
for i in range(timesteps, train.shape[0]):
    X_train.append(train_scaled[i-timesteps:i, 0]) 
    y_train.append(train_scaled[i, 0]) 
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
test = test_data.iloc[:, 0:1].values 
scaler = MinMaxScaler() 
test_scaled = scaler.fit_transform(test)
timesteps = 7
X_test = []
y_test = []
for i in range(timesteps, test.shape[0]):
    X_test.append(test_scaled[i-timesteps:i, 0]) 
    y_test.append(test_scaled[i, 0]) 
X_test, y_test = np.array(X_test), np.array(y_test)

# %% [markdown]
# # Machine Learning

# %% [markdown]
# # SVM

# %%
model = SVR()
model.fit(X_train, y_train)
# Out:
# SVR()

# %%
real_stock_price = test_data.iloc[:, 0:1].values
combine = pd.concat((train_data['Open'], test_data['Open']), axis=0)

test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1, 1)
test_inputs = scaler.transform(test_inputs)
X_test = []
for i in range(timesteps, test_data.shape[0] + timesteps):
    X_test.append(test_inputs[i - timesteps:i, 0])

X_test = np.array(X_test)


X_test = X_test.reshape(X_test.shape[0], timesteps)

predicted_stock_price = model.predict(X_test)


predicted_stock_price = predicted_stock_price.reshape(-1, 1)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

plt.figure(figsize=(16, 8))
plt.plot(data.index[-600:], data['Open'].tail(600), color='green', label='Train Stock Price')
plt.plot(test_data.index, real_stock_price, color='red', label='Real Stock Price')
plt.plot(test_data.index, predicted_stock_price, color='blue', label='Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
mse = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse))
mae = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae))
rmse = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse))
r2 = r2_score(real_stock_price, predicted_stock_price)
print('R2 Score: ' + str(r2))
# Out:
# MSE: 35363.90899359423
# MAE: 148.6509732855761
# RMSE: 188.05294199664687
# R2 Score: 0.5868532376193767

# %% [markdown]
# # KNN

# %%
knn = KNeighborsRegressor(n_neighbors=2)
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=2)

# %%
real_stock_price = test_data.iloc[:, 0:1].values
combine = pd.concat((train_data['Open'], test_data['Open']), axis=0)

test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1, 1)
test_inputs = scaler.transform(test_inputs)
X_test = []
for i in range(timesteps, test_data.shape[0] + timesteps):
    X_test.append(test_inputs[i - timesteps:i, 0])

X_test = np.array(X_test)


X_test = X_test.reshape(X_test.shape[0], timesteps)

predicted_stock_price = knn.predict(X_test)


predicted_stock_price = predicted_stock_price.reshape(-1, 1)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

plt.figure(figsize=(16, 8))
plt.plot(data.index[-600:], data['Open'].tail(600), color='green', label='Train Stock Price')
plt.plot(test_data.index, real_stock_price, color='red', label='Real Stock Price')
plt.plot(test_data.index, predicted_stock_price, color='blue', label='Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
mse1 = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse1))
mae1 = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae1))
rmse1 = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse1))
r21 = r2_score(real_stock_price, predicted_stock_price)
print('R2 Score: ' + str(r21))
# Out:
# MSE: 39091.6706148598
# MAE: 162.6069696062336
# RMSE: 197.7161364554239
# R2 Score: 0.5433028301960461

# %% [markdown]
# # Decision Tree

# %%
DT = DecisionTreeRegressor(random_state=0)
DT.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
real_stock_price = test_data.iloc[:, 0:1].values
combine = pd.concat((train_data['Open'], test_data['Open']), axis=0)

test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1, 1)
test_inputs = scaler.transform(test_inputs)
X_test = []
for i in range(timesteps, test_data.shape[0] + timesteps):
    X_test.append(test_inputs[i - timesteps:i, 0])

X_test = np.array(X_test)


X_test = X_test.reshape(X_test.shape[0], timesteps)

predicted_stock_price = DT.predict(X_test)


predicted_stock_price = predicted_stock_price.reshape(-1, 1)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

plt.figure(figsize=(16, 8))
plt.plot(data.index[-600:], data['Open'].tail(600), color='green', label='Train Stock Price')
plt.plot(test_data.index, real_stock_price, color='red', label='Real Stock Price')
plt.plot(test_data.index, predicted_stock_price, color='blue', label='Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
mse2 = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse2))
mae2 = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae2))
rmse2 = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse2))
r22 = r2_score(real_stock_price, predicted_stock_price)
print('R2 Score: ' + str(r22))
# Out:
# MSE: 24430.442831850214
# MAE: 126.0939652504454
# RMSE: 156.30240827271413
# R2 Score: 0.714585897126584

# %% [markdown]
# # Random Forest

# %%
RF = RandomForestRegressor(max_depth=2, random_state=0)
RF.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=0)

# %%
real_stock_price = test_data.iloc[:, 0:1].values
combine = pd.concat((train_data['Open'], test_data['Open']), axis=0)

test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1, 1)
test_inputs = scaler.transform(test_inputs)
X_test = []
for i in range(timesteps, test_data.shape[0] + timesteps):
    X_test.append(test_inputs[i - timesteps:i, 0])

X_test = np.array(X_test)


X_test = X_test.reshape(X_test.shape[0], timesteps)

predicted_stock_price = RF.predict(X_test)


predicted_stock_price = predicted_stock_price.reshape(-1, 1)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

plt.figure(figsize=(16, 8))
plt.plot(data.index[-600:], data['Open'].tail(600), color='green', label='Train Stock Price')
plt.plot(test_data.index, real_stock_price, color='red', label='Real Stock Price')
plt.plot(test_data.index, predicted_stock_price, color='blue', label='Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
mse3 = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse3))
mae3 = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae3))
rmse3 = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse3))
r23 = r2_score(real_stock_price, predicted_stock_price)
print('R2 Score: ' + str(r23))
# Out:
# MSE: 18394.281592517316
# MAE: 111.50630395400032
# RMSE: 135.62551969492068
# R2 Score: 0.785104698475426

# %% [markdown]
# # Extreme Gradient Boosting

# %%
gb = GradientBoostingRegressor(random_state=0)
gb.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=0)

# %%
real_stock_price = test_data.iloc[:, 0:1].values
combine = pd.concat((train_data['Open'], test_data['Open']), axis=0)

test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1, 1)
test_inputs = scaler.transform(test_inputs)
X_test = []
for i in range(timesteps, test_data.shape[0] + timesteps):
    X_test.append(test_inputs[i - timesteps:i, 0])

X_test = np.array(X_test)


X_test = X_test.reshape(X_test.shape[0], timesteps)

predicted_stock_price = gb.predict(X_test)


predicted_stock_price = predicted_stock_price.reshape(-1, 1)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

plt.figure(figsize=(16, 8))
plt.plot(data.index[-600:], data['Open'].tail(600), color='green', label='Train Stock Price')
plt.plot(test_data.index, real_stock_price, color='red', label='Real Stock Price')
plt.plot(test_data.index, predicted_stock_price, color='blue', label='Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
mse4 = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse4))
mae4 = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae4))
rmse4 = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse4))
r24 = r2_score(real_stock_price, predicted_stock_price)
print('R2 Score: ' + str(r24))
# Out:
# MSE: 17141.30866009205
# MAE: 106.73400603014517
# RMSE: 130.92482064181738
# R2 Score: 0.7997428345048967

# %% [markdown]
# # AdaBoost

# %%
ada = AdaBoostRegressor(random_state=0, n_estimators=100)
ada.fit(X_train, y_train)
# Out:
# AdaBoostRegressor(n_estimators=100, random_state=0)

# %%
real_stock_price = test_data.iloc[:, 0:1].values
combine = pd.concat((train_data['Open'], test_data['Open']), axis=0)

test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1, 1)
test_inputs = scaler.transform(test_inputs)
X_test = []
for i in range(timesteps, test_data.shape[0] + timesteps):
    X_test.append(test_inputs[i - timesteps:i, 0])

X_test = np.array(X_test)


X_test = X_test.reshape(X_test.shape[0], timesteps)

predicted_stock_price = ada.predict(X_test)


predicted_stock_price = predicted_stock_price.reshape(-1, 1)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

plt.figure(figsize=(16, 8))
plt.plot(data.index[-600:], data['Open'].tail(600), color='green', label='Train Stock Price')
plt.plot(test_data.index, real_stock_price, color='red', label='Real Stock Price')
plt.plot(test_data.index, predicted_stock_price, color='blue', label='Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
mse5 = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse5))
mae5 = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae5))
rmse5 = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse5))
r25 = r2_score(real_stock_price, predicted_stock_price)
print('R2 Score: ' + str(r25))
# Out:
# MSE: 19518.84221920056
# MAE: 115.76422299372847
# RMSE: 139.70985011516032
# R2 Score: 0.7719667678779045

# %% [markdown]
# # Naive Bayes

# %%
br = linear_model.BayesianRidge()
br.fit(X_train, y_train)
# Out:
# BayesianRidge()

# %%
real_stock_price = test_data.iloc[:, 0:1].values
combine = pd.concat((train_data['Open'], test_data['Open']), axis=0)

test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1, 1)
test_inputs = scaler.transform(test_inputs)
X_test = []
for i in range(timesteps, test_data.shape[0] + timesteps):
    X_test.append(test_inputs[i - timesteps:i, 0])

X_test = np.array(X_test)


X_test = X_test.reshape(X_test.shape[0], timesteps)

predicted_stock_price = br.predict(X_test)


predicted_stock_price = predicted_stock_price.reshape(-1, 1)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

plt.figure(figsize=(16, 8))
plt.plot(data.index[-600:], data['Open'].tail(600), color='green', label='Train Stock Price')
plt.plot(test_data.index, real_stock_price, color='red', label='Real Stock Price')
plt.plot(test_data.index, predicted_stock_price, color='blue', label='Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
mse6 = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse6))
mae6 = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae6))
rmse6 = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse6))
r26 = r2_score(real_stock_price, predicted_stock_price)
print('R2 Score: ' + str(r26))
# Out:
# MSE: 15181.76487793394
# MAE: 100.1115415876529
# RMSE: 123.21430468064145
# R2 Score: 0.8226356422397076

# %% [markdown]
# # Linear Regression

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
real_stock_price = test_data.iloc[:, 0:1].values
combine = pd.concat((train_data['Open'], test_data['Open']), axis=0)

test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1, 1)
test_inputs = scaler.transform(test_inputs)
X_test = []
for i in range(timesteps, test_data.shape[0] + timesteps):
    X_test.append(test_inputs[i - timesteps:i, 0])

X_test = np.array(X_test)


X_test = X_test.reshape(X_test.shape[0], timesteps)

predicted_stock_price = lr.predict(X_test)


predicted_stock_price = predicted_stock_price.reshape(-1, 1)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

plt.figure(figsize=(16, 8))
plt.plot(data.index[-600:], data['Open'].tail(600), color='green', label='Train Stock Price')
plt.plot(test_data.index, real_stock_price, color='red', label='Real Stock Price')
plt.plot(test_data.index, predicted_stock_price, color='blue', label='Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
mse7 = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse7))
mae7 = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae7))
rmse7 = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse7))
r27 = r2_score(real_stock_price, predicted_stock_price)
print('R2 Score: ' + str(r27))
# Out:
# MSE: 15088.451175569073
# MAE: 99.72210512033591
# RMSE: 122.83505678579333
# R2 Score: 0.8237258004013741

# %% [markdown]
# # ANN

# %%
ann = MLPRegressor(random_state=1, max_iter=500)
ann.fit(X_train, y_train)
# Out:
# MLPRegressor(max_iter=500, random_state=1)

# %%
real_stock_price = test_data.iloc[:, 0:1].values
combine = pd.concat((train_data['Open'], test_data['Open']), axis=0)

test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1, 1)
test_inputs = scaler.transform(test_inputs)
X_test = []
for i in range(timesteps, test_data.shape[0] + timesteps):
    X_test.append(test_inputs[i - timesteps:i, 0])

X_test = np.array(X_test)


X_test = X_test.reshape(X_test.shape[0], timesteps)

predicted_stock_price = ann.predict(X_test)


predicted_stock_price = predicted_stock_price.reshape(-1, 1)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

plt.figure(figsize=(16, 8))
plt.plot(data.index[-600:], data['Open'].tail(600), color='green', label='Train Stock Price')
plt.plot(test_data.index, real_stock_price, color='red', label='Real Stock Price')
plt.plot(test_data.index, predicted_stock_price, color='blue', label='Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
mse8 = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse8))
mae8 = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae8))
rmse8 = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse8))
r28 = r2_score(real_stock_price, predicted_stock_price)
print('R2 Score: ' + str(r28))
# Out:
# MSE: 54063.519819406465
# MAE: 190.48389615602494
# RMSE: 232.51563349462432
# R2 Score: 0.36839085915715974

# %% [markdown]
# # Deep Learning

# %% [markdown]
# # RNN

# %%
train = train_data.iloc[:, 0:1].values

# %%
scaler = MinMaxScaler() 
train_scaled = scaler.fit_transform(train)

# %%
timesteps = 7
X_train = []
y_train = []
for i in range(timesteps, train.shape[0]):
    X_train.append(train_scaled[i-timesteps:i, 0]) 
    y_train.append(train_scaled[i, 0]) 
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1)) #Reshaping
from numpy.random import seed 
seed(2019)

# %%
model = Sequential()
model.add(SimpleRNN(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))  # Use SimpleRNN

model.add(Dropout(0.20))

model.add(SimpleRNN(units=50, return_sequences=True))  # Use SimpleRNN
model.add(Dropout(0.25))

model.add(SimpleRNN(units=50, return_sequences=True))  # Use SimpleRNN
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50))  # Use SimpleRNN
model.add(Dropout(0.25))

model.add(Dense(units=1))

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(X_train, y_train, epochs = 40, batch_size = 32)
# Out:
# Epoch 1/40
# 14/14 [==============================] - 3s 23ms/step - loss: 0.4509
# Epoch 2/40
# 14/14 [==============================] - 0s 24ms/step - loss: 0.3384
# Epoch 3/40
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2735
# Epoch 4/40
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2402
# Epoch 5/40
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1906
# Epoch 6/40
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1669
# Epoch 7/40
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1457
# Epoch 8/40
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1253
# Epoch 9/40
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1273
# Epoch 10/40
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1338
# Epoch 11/40
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0983
# Epoch 12/40
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0853
# Epoch 13/40
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0842
# Epoch 14/40
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0748
# Epoch 15/40
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0661: 0s - loss: 0.0
# Epoch 16/40
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0633
# Epoch 17/40
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0588
# Epoch 18/40
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0667
# Epoch 19/40
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0474
# Epoch 20/40
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0466
# Epoch 21/40
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0440
# Epoch 22/40
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0476
# Epoch 23/40
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0444
# Epoch 24/40
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0411
# Epoch 25/40
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0345
# Epoch 26/40
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0291
# Epoch 27/40
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0307
# Epoch 28/40
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0308
# Epoch 29/40
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0320
# Epoch 30/40
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0309
# Epoch 31/40
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0287
# Epoch 32/40
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0303
# Epoch 33/40
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0287
# Epoch 34/40
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0244
# Epoch 35/40
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0256
# Epoch 36/40
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0232
# Epoch 37/40
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0229
# Epoch 38/40
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0248
# Epoch 39/40
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0209
# Epoch 40/40
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0214

# %%
real_stock_price = test_data.iloc[:,0:1].values
combine = pd.concat((train_data['Open'], test_data['Open']), axis = 0)

test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1,1)
test_inputs = scaler.transform(test_inputs)
X_test = []
for i in range(timesteps, test_data.shape[0]+timesteps):
    X_test.append(test_inputs[i-timesteps:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = model.predict(X_test)

predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

plt.figure(figsize=(16,8))
plt.plot(data.index[-600:], data['Open'].tail(600), color='green', label = 'Train Stock Price')
plt.plot(test_data.index, real_stock_price, color = 'red', label = 'Real Stock Price')
plt.plot(test_data.index, predicted_stock_price, color = 'blue', label = 'Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
mse9 = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse9))
mae9 = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae9))
rmse9 = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse9))
r29 = r2_score(real_stock_price, predicted_stock_price)
print('R2 Score: ' + str(r29))
# Out:
# MSE: 59278.833060760495
# MAE: 190.756015625
# RMSE: 243.47244825803287
# R2 Score: 0.30746179781225835

# %% [markdown]
# ## LSTM

# %%
model = Sequential()
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))

model.add(Dropout(0.20))

model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.25))

model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 50))
model.add(Dropout(0.25))


model.add(Dense(units = 1))

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 7, 50)             10400
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 7, 50)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 7, 50)             20200
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 7, 50)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 7, 50)             20200
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 7, 50)             0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs = 40, batch_size = 32)
# Out:
# Epoch 1/40
# 14/14 [==============================] - 6s 9ms/step - loss: 0.1483
# Epoch 2/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0389
# Epoch 3/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0255
# Epoch 4/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0174
# Epoch 5/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0136
# Epoch 6/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0125
# Epoch 7/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0101
# Epoch 8/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0120
# Epoch 9/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0110
# Epoch 10/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0097
# Epoch 11/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0102
# Epoch 12/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0104
# Epoch 13/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0106
# Epoch 14/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0096
# Epoch 15/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0096
# Epoch 16/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0099
# Epoch 17/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0108
# Epoch 18/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0099
# Epoch 19/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0096
# Epoch 20/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0097
# Epoch 21/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0090
# Epoch 22/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0096
# Epoch 23/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0099
# Epoch 24/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0097
# Epoch 25/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0096
# Epoch 26/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0108
# Epoch 27/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0103
# Epoch 28/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0102
# Epoch 29/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0084
# Epoch 30/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0079
# Epoch 31/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0083A: 0s - loss: 0.008
# Epoch 32/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0080
# Epoch 33/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0095
# Epoch 34/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0087
# Epoch 35/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0082
# Epoch 36/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0083
# Epoch 37/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0097
# Epoch 38/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0079
# Epoch 39/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0078
# Epoch 40/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0088

# %%
real_stock_price = test_data.iloc[:,0:1].values
combine = pd.concat((train_data['Open'], test_data['Open']), axis = 0)

test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1,1)
test_inputs = scaler.transform(test_inputs)
X_test = []
for i in range(timesteps, test_data.shape[0]+timesteps):
    X_test.append(test_inputs[i-timesteps:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = model.predict(X_test)

predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

plt.figure(figsize=(16,8))
plt.plot(data.index[-600:], data['Open'].tail(600), color='green', label = 'Train Stock Price')
plt.plot(test_data.index, real_stock_price, color = 'red', label = 'Real Stock Price')
plt.plot(test_data.index, predicted_stock_price, color = 'blue', label = 'Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
mse10 = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse10))
mae10 = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae10))
rmse10 = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse10))
r210 = r2_score(real_stock_price, predicted_stock_price)
print('R2 Score: ' + str(r210))
# Out:
# MSE: 95325.50983276367
# MAE: 258.8875
# RMSE: 308.7482952710244
# R2 Score: -0.1136615515785444

# %% [markdown]
# ## GRU

# %%
model = Sequential()
model.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))  

model.add(Dropout(0.20))

model.add(GRU(units=50, return_sequences=True)) 
model.add(Dropout(0.25))

model.add(GRU(units=50, return_sequences=True))  
model.add(Dropout(0.2))

model.add(GRU(units=50))  
model.add(Dropout(0.25))

model.add(Dense(units=1))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 7, 50)             7950
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 7, 50)             0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 7, 50)             15300
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 7, 50)             0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 7, 50)             15300
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 7, 50)             0
# _________________________________________________________________
# gru_3 (GRU)                  (None, 50)                15300
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 53,901
# Trainable params: 53,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(X_train, y_train, epochs = 40, batch_size = 32)
# Out:
# Epoch 1/40
# 14/14 [==============================] - 4s 8ms/step - loss: 0.0713
# Epoch 2/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0258
# Epoch 3/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0150
# Epoch 4/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0118
# Epoch 5/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0106
# Epoch 6/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0087
# Epoch 7/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0093
# Epoch 8/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0079
# Epoch 9/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0091
# Epoch 10/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0088
# Epoch 11/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0085
# Epoch 12/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0085
# Epoch 13/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0090
# Epoch 14/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0091
# Epoch 15/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0081
# Epoch 16/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0077
# Epoch 17/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0078
# Epoch 18/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0071
# Epoch 19/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0069
# Epoch 20/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0074
# Epoch 21/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0094
# Epoch 22/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0078
# Epoch 23/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0070
# Epoch 24/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0067
# Epoch 25/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0070
# Epoch 26/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0080
# Epoch 27/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0065
# Epoch 28/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0059
# Epoch 29/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0064
# Epoch 30/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0061
# Epoch 31/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0058
# Epoch 32/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0064
# Epoch 33/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0059
# Epoch 34/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0060
# Epoch 35/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0058
# Epoch 36/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0055
# Epoch 37/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0063
# Epoch 38/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0056
# Epoch 39/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0057
# Epoch 40/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0059

# %%
real_stock_price = test_data.iloc[:,0:1].values
combine = pd.concat((train_data['Open'], test_data['Open']), axis = 0)

test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1,1)
test_inputs = scaler.transform(test_inputs)
X_test = []
for i in range(timesteps, test_data.shape[0]+timesteps):
    X_test.append(test_inputs[i-timesteps:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = model.predict(X_test)

predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

plt.figure(figsize=(16,8))
plt.plot(data.index[-600:], data['Open'].tail(600), color='green', label = 'Train Stock Price')
plt.plot(test_data.index, real_stock_price, color = 'red', label = 'Real Stock Price')
plt.plot(test_data.index, predicted_stock_price, color = 'blue', label = 'Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
mse11 = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse11))
mae11 = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae11))
rmse11 = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse11))
r211 = r2_score(real_stock_price, predicted_stock_price)
print('R2 Score: ' + str(r211))
# Out:
# MSE: 92570.1601044464
# MAE: 246.8039453125
# RMSE: 304.25344715293926
# R2 Score: -0.0814715632012184

# %% [markdown]
# # Comparison

# %%
results = {
    'R-squared': [r2, r21, r22, r23, r24, r25, r26, r27, r28, r29, r210, r211],
    'Mean Squared Error': [mse, mse1, mse2, mse3, mse4, mse5, mse6, mse7, mse8, mse9, mse10, mse11],
    'Mean Absolute Error': [mae, mae1, mae2, mae3, mae4, mae5, mae6, mae7, mae8, mae9, mae10, mae11],
    'Root Mean Squared Error': [rmse, rmse1, rmse2, rmse3, rmse4, rmse5, rmse6, rmse7, rmse8, rmse9, rmse10, rmse11]
}


index = ['SVM','KNN','Decision Tree','Random Forest','Gradient Boosting','Adaboost','Naive Bayes','Linear Regression','ANN','RNN','LSTM','GRU']

# %%
results =pd.DataFrame(results,index=index)

# %%
print(results)
# Out:
#                    R-squared  Mean Squared Error  Mean Absolute Error  \
# SVM                 0.586853        35363.908994           148.650973
# KNN                 0.543303        39091.670615           162.606970
# Decision Tree       0.714586        24430.442832           126.093965
# Random Forest       0.785105        18394.281593           111.506304
# Gradient Boosting   0.799743        17141.308660           106.734006
# Adaboost            0.771967        19518.842219           115.764223
# Naive Bayes         0.822636        15181.764878           100.111542
# Linear Regression   0.823726        15088.451176            99.722105
# ANN                 0.368391        54063.519819           190.483896
# RNN                 0.307462        59278.833061           190.756016
# LSTM               -0.113662        95325.509833           258.887500
# GRU                -0.081472        92570.160104           246.803945
#
#                    Root Mean Squared Error
# SVM                             188.052942
# KNN                             197.716136
# Decision Tree                   156.302408
# Random Forest                   135.625520
# Gradient Boosting               130.924821
# Adaboost                        139.709850
# Naive Bayes                     123.214305
# Linear Regression               122.835057
# ANN                             232.515633
# RNN                             243.472448
# LSTM                            308.748295
# GRU                             304.253447

# %%
fig =results.plot(kind='bar',title='Comaprison of models',figsize =(19,19)).get_figure()
fig.savefig('Final Result.png')

# %%
def visualize_metric(metric, color):
    plt.figure(figsize=(10, 6))
    plt.bar(index, results[metric], color=color)
    plt.xlabel('Models')
    plt.ylabel(metric)
    plt.title(f'{metric} for Different Models')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()


visualize_metric('R-squared', 'green')

# %%
def visualize_metric(metric, color):
    plt.figure(figsize=(10, 6))
    plt.bar(index, results[metric], color=color)
    plt.xlabel('Models')
    plt.ylabel(metric)
    plt.title(f'{metric} for Different Models')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()


visualize_metric('Mean Squared Error', 'orange')

# %%
visualize_metric('Mean Absolute Error', 'purple')

# %%
visualize_metric('Root Mean Squared Error', 'pink')
